# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="dq96YdSMsS3dS5azjTCD")
project = rf.workspace("hcmute-fivds").project("people-detection-2yubh")
dataset = project.version(5).download("yolov5")

# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5.git

# %%
# %cd /content/yolov5/
# !pip install -r requirements.txt

# %%
# %cat /content/people-detection-5/data.yaml

# %%
# %cd /
from glob import glob

train_img_list = glob('/content/people-detection-5/train/images/*.jpg')

print(len(train_img_list))

# %%
# %cd /
from glob import glob

val_img_list = glob('/content/people-detection-5/test/images/*.jpg')

print(len(val_img_list))
# Out:
# /
# 14

# %%
with open('/content/people-detection-5/train.txt','w') as f :
  f.write('\n'.join(train_img_list)+'\n')

with open('/content/people-detection-5/val.txt','w') as f :
  f.write('\n'.join(val_img_list)+'\n')

# %%
import yaml

with open('/content/people-detection-5/data.yaml', 'r') as f:
  data = yaml.safe_load(f)
print(data)

data['train'] = '/content/people-detection-5/train.txt'
data['val'] = '/content/people-detection-5/val.txt'

with open('/content/people-detection-5/data.yaml','w') as f:
  yaml.dump(data, f)

print(data)
# Out:
# {'names': ['people'], 'nc': 1, 'roboflow': {'license': 'CC BY 4.0', 'project': 'people-detection-2yubh', 'url': 'https://universe.roboflow.com/hcmute-fivds/people-detection-2yubh/dataset/5', 'version': 5, 'workspace': 'hcmute-fivds'}, 'test': '../test/images', 'train': 'people-detection-5/train/images', 'val': 'people-detection-5/valid/images'}
# {'names': ['people'], 'nc': 1, 'roboflow': {'license': 'CC BY 4.0', 'project': 'people-detection-2yubh', 'url': 'https://universe.roboflow.com/hcmute-fivds/people-detection-2yubh/dataset/5', 'version': 5, 'workspace': 'hcmute-fivds'}, 'test': '../test/images', 'train': '/content/people-detection-5/train.txt', 'val': '/content/people-detection-5/val.txt'}

# %%
# %cd /content/yolov5/

# !python train.py --img 416 --batch 16 --epochs 50 --data /content/people-detection-5/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name human
# Out:
# /content/yolov5
# 2023-11-30 07:38:22.716092: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-30 07:38:22.716155: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-30 07:38:22.716197: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from IPython.display import Video
import os

val_video_path = "/content/횡단보도_yolo.mp4"
print("이미지 경로:", val_video_path)

# YOLOv5 감지 실행
# !python detect.py --weights /content/yolov5/runs/train/human/weights/best.pt --img 416 --conf 0.5 --source "{val_video_path}"

# 디버깅을 위해 출력 디렉토리 출력
output_path = os.path.join('/content/yolov5/inference/output', os.path.basename(val_video_path))
# Out:
# 이미지 경로: /content/횡단보도_yolo.mp4
# detect: weights=['/content/yolov5/runs/train/human/weights/best.pt'], source=/content/횡단보도_yolo.mp4, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x58ad714cb2c0] moov atom not found
# Traceback (most recent call last):
#   File "/content/yolov5/detect.py", line 285, in <module>
#     main(opt)
#   File "/content/yolov5/detect.py", line 280, in main
#     run(**vars(opt))
# ...

# %%
from IPython.display import Video
import os

val_video_path = "/content/2.mp4"
print("이미지 경로:", val_video_path)

# YOLOv5 감지 실행
# !python detect.py --weights /content/yolov5/runs/train/human/weights/best.pt --img 416 --conf 0.5 --source "{val_video_path}"

# 디버깅을 위해 출력 디렉토리 출력
output_path = os.path.join('/content/yolov5/inference/output', os.path.basename(val_video_path))
# Out:
# 이미지 경로: /content/2.mp4
# detect: weights=['/content/yolov5/runs/train/human/weights/best.pt'], source=/content/2.mp4, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/510) /content/2.mp4: 256x416 6 peoples, 41.5ms
# video 1/1 (2/510) /content/2.mp4: 256x416 6 peoples, 5.4ms
# video 1/1 (3/510) /content/2.mp4: 256x416 7 peoples, 5.7ms
# video 1/1 (4/510) /content/2.mp4: 256x416 5 peoples, 9.0ms
# ...
