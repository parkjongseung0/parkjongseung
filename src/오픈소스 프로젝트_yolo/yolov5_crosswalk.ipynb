# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="dq96YdSMsS3dS5azjTCD")
project = rf.workspace("project-sgd9c").project("crosswalk-deteccting")
dataset = project.version(1).download("yolov5")

# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5.git

# %%
# %cd /content/yolov5/
# !pip install -r requirements.txt

# %%
# %cat /content/crosswalk-deteccting-1/data.yaml

# %%
# %cd /
from glob import glob

train_img_list = glob('/content/crosswalk-deteccting-1/train/images/*.jpg')

print(len(train_img_list))

# %%
# %cd /
from glob import glob

val_img_list = glob('/content/crosswalk-deteccting-1/test/images/*.jpg')

print(len(val_img_list))
# Out:
# /
# 44

# %%
with open('/content/crosswalk-deteccting-1/train.txt','w') as f :
  f.write('\n'.join(train_img_list)+'\n')

with open('/content/crosswalk-deteccting-1/val.txt','w') as f :
  f.write('\n'.join(val_img_list)+'\n')

# %%
import yaml

with open('/content/crosswalk-deteccting-1/data.yaml', 'r') as f:
  data = yaml.safe_load(f)

print(data)

data['train'] = '/content/crosswalk-deteccting-1/train.txt'
data['val'] = '/content/crosswalk-deteccting-1/val.txt'

with open('/content/crosswalk-deteccting-1/data.yaml','w') as f:
  yaml.dump(data, f)

print(data)
# Out:
# {'names': ['crosswalk'], 'nc': 1, 'roboflow': {'license': 'CC BY 4.0', 'project': 'crosswalk-deteccting', 'url': 'https://universe.roboflow.com/project/crosswalk-deteccting/dataset/1', 'version': 1, 'workspace': 'project'}, 'test': '../test/images', 'train': 'crosswalk-deteccting-1/train/images', 'val': 'crosswalk-deteccting-1/valid/images'}
# {'names': ['crosswalk'], 'nc': 1, 'roboflow': {'license': 'CC BY 4.0', 'project': 'crosswalk-deteccting', 'url': 'https://universe.roboflow.com/project/crosswalk-deteccting/dataset/1', 'version': 1, 'workspace': 'project'}, 'test': '../test/images', 'train': '/content/crosswalk-deteccting-1/train.txt', 'val': '/content/crosswalk-deteccting-1/val.txt'}

# %%
# %cd /content/yolov5/

# !python train.py --img 416 --batch 16 --epochs 50 --data /content/crosswalk-deteccting-1/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name crosswalk
# Out:
# /content/yolov5
# 2023-11-26 15:07:23.923160: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-26 15:07:23.923224: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-26 15:07:23.923273: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from IPython.display import Image
import os

val_img_path = "/content/crosswalk-deteccting-1/test/images/0_횡단보도.png"
print("이미지 경로:", val_img_path)

# YOLOv5 감지 실행
# !python detect.py --weights /content/yolov5/runs/train/crosswalk/weights/best.pt --img 416 --conf 0.5 --source "{val_img_path}"

# 디버깅을 위해 출력 디렉토리 출력
output_path = os.path.join('/content/yolov5/inference/output', os.path.basename(val_img_path))
# Out:
# 이미지 경로: /content/crosswalk-deteccting-1/test/images/0_횡단보도.png
# detect: weights=['/content/yolov5/runs/train/crosswalk/weights/best.pt'], source=/content/crosswalk-deteccting-1/test/images/0_횡단보도.png, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/crosswalk-deteccting-1/test/images/0_횡단보도.png: 224x416 1 crosswalk, 45.8ms
# Speed: 0.5ms pre-process, 45.8ms inference, 1.9ms NMS per image at shape (1, 3, 416, 416)
# ...
